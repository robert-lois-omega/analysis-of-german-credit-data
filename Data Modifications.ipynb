# %%
import pandas as pd

# %%
data = pd.read_csv('index.csv')

# %%
# Manipulate Purpose Labels
classification_purpose_data = [
    [1, "new car"],
    [2, "used car"],
    [3, "items of furniture"],
    [4, "radio / television"],
    [5, "household appliances"],
    [6, "repair"],
    [7, "education"],
    [8, "vacation"],
    [9, "retraining"],
    [10, "business"],
    [11, "other"]
]

# %%
# Manipulate Purpose Labels
classification_apartment_type_data = [
    [1, "rented flat"],
    [2, "owner-occupied flat"],
    [3, "free apartment"]
]

# %%
def translate_purpose(x):
    for i in classification_purpose_data:
        if x == int(i[0]):
            return i[1]
        else:
            pass

# %%
def translate_apartment_type(x):
    for i in classification_data:
        if x == int(i[0]):
            return i[1]
        else:
            pass

# %%
data['Translated_purpose'] = data['Purpose'].apply(translate_purpose)

# %%
data['Translated_purpose']
# Out:
# 0      items of furniture
# 1      radio / television
# 2      items of furniture
# 3      radio / television
# 4                used car
#               ...
# 495              used car
# 496    items of furniture
# 497    radio / television
# 498    items of furniture
# 499              used car
# Name: Translated_purpose, Length: 500, dtype: object

# %%
data['Type.of.apartment_translated'] = data['Type.of.apartment'].apply(translate_apartment_type)

# %%
data['Type.of.apartment_translated']
# Out:
# 0       new car
# 1       new car
# 2      used car
# 3       new car
# 4      used car
#          ...
# 495     new car
# 496    used car
# 497    used car
# 498    used car
# 499    used car
# Name: Type.of.apartment_translated, Length: 500, dtype: object
